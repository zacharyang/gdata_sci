# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
## Read in data ## 

attendance_records= pd.DataFrame.from_csv('attendance_records_20160324.csv')
demo_info=pd.DataFrame.from_csv('demographic_info_20160324.csv')
psle_grade_range=pd.DataFrame.from_csv('PSLE Grade Score Range.csv')
results=pd.DataFrame.from_csv('results_info_20160324.csv')

# %%
demo_info.dropna().describe(include='all')
# Out:
#                        School Programme Gender        PCHI Flat_Type
# count                     149       149    149  149.000000       149
# unique                      3         2      2         NaN         2
# top     Normal Primary School      PASS      M         NaN     OWNED
# freq                       62        98     75         NaN       122
# mean                      NaN       NaN    NaN  589.120805       NaN
# std                       NaN       NaN    NaN  256.005646       NaN
# min                       NaN       NaN    NaN    0.000000       NaN
# 25%                       NaN       NaN    NaN  420.000000       NaN
# 50%                       NaN       NaN    NaN  624.000000       NaN
# 75%                       NaN       NaN    NaN  776.000000       NaN
# max                       NaN       NaN    NaN  994.000000       NaN

# %%
results.dropna().describe(include='all')
# Out:
#              NRIC Programme  2014_Result  2015_Result PSLE_Result
# count         154       154   154.000000   154.000000         154
# unique        154         2          NaN          NaN           7
# top     T0420191I      PASS          NaN          NaN           D
# freq            1       101          NaN          NaN          52
# mean          NaN       NaN    27.603636    33.991364         NaN
# std           NaN       NaN    10.676081    17.020121         NaN
# min           NaN       NaN     5.860000     5.750000         NaN
# 25%           NaN       NaN    19.400000    18.667500         NaN
# 50%           NaN       NaN    28.865000    33.840000         NaN
# 75%           NaN       NaN    35.172500    45.130000         NaN
# max           NaN       NaN    49.170000    81.960000         NaN

# %%
sns.countplot(results['PSLE_Result'])
